# %% [markdown]
# # 데이터 유형에 따른 시각화

# %% [markdown]
# ## Image

# %%
from PIL import Image

# 이미지 파일 경로
image_path = "../src/image_sample.png"

# 이미지 로드
image = Image.open(image_path)

# 이미지 jupyter notebook에 표시
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
# PNG (512, 512) RGB

# %%
# 이미지 사이즈 출력
# Out:
# (512, 512)

# %%
# 이미지를 회전
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# 이미지를 축소 (100, 100)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
# 이미지를 뒤집기
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# 이미지를 흑백으로 변환
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %% [markdown]
# ## 소리 데이터

# %%
# %pip install librosa
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.1/260.1 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.4/156.4 kB 16.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa

file_path = "../src/speech_sample.wav"

# WAV 파일 로드
data, sampling_rate = librosa.load(file_path, sr=None)

# %%
# sampling rate 출력
# Out:
# 16000

# %%
# data 출력
# Out:
# [-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ...  1.0696411e-01
#   9.6649170e-02  1.0986328e-01]

# %%
# data shape 출력
# Out:
# (172320,)

# %%
import matplotlib.pyplot as plt
# data 시각화

# %%
# (librosa는 데이터를 저장하는 직접적인 기능은 제공하지 않지만, 이를 해결하기 위해 soundfile 라이브러리를 사용할 수 있습니다. librosa로 처리한 오디오 데이터를 .wav 파일로 저장하려면 soundfile.write를 사용하면 됩니다.)
import soundfile

# sampling rate 2배 빠르게 저장하기

# %% [markdown]
# ## CSV 데이터

# %%
import pandas as pd

# CSV 파일 경로
file_path = "../src/csv_sample.csv"

# CSV 파일 로드
df = pd.read_csv(file_path)

# %%
# 데이터 print
# Out:
#            date   open   high    low  close    volume    change
# 0    2024-01-02  78200  79800  78200  79600  17142847  1.401274
# 1    2024-01-03  78500  78800  77000  77000  21753644 -3.266332
# 2    2024-01-04  76100  77300  76100  76600  15324439 -0.519481
# 3    2024-01-05  76700  77100  76400  76600  11304316  0.000000
# 4    2024-01-08  77000  77500  76400  76500  11088724 -0.130548
# ..          ...    ...    ...    ...    ...       ...       ...
# 209  2024-11-11  56700  56800  55000  55000  29811326 -3.508772
# 210  2024-11-12  54600  54600  53000  53000  37962881 -3.636364
# 211  2024-11-13  52000  53000  50500  50600  52527995 -4.528302
# 212  2024-11-14  50200  51800  49900  49900  48510715 -1.383399
# 213  2024-11-15  50300  54200  50300  53500  43748624  7.214429
#
# [214 rows x 7 columns]

# %%
# 데이터 타입 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# 데이터 크기 출력
# Out:
# (214, 7)

# %%
# 데이터 열 출력
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'change'], dtype='object')

# %%
# date 가 2024-11-15 인 데이터 출력
# Out:
#            date   open   high    low  close    volume    change
# 213  2024-11-15  50300  54200  50300  53500  43748624  7.214429

# %%
# change 가 0 이상인 데이터 출력
# Out:
#            date   open   high    low  close    volume    change
# 0    2024-01-02  78200  79800  78200  79600  17142847  1.401274
# 3    2024-01-05  76700  77100  76400  76600  11304316  0.000000
# 9    2024-01-15  73200  74000  73200  73900  13212339  1.094391
# 12   2024-01-18  71600  72000  70700  71700  17853397  0.985915
# 13   2024-01-19  73500  74700  73000  74700  23363427  4.184100
# ..          ...    ...    ...    ...    ...       ...       ...
# 200  2024-10-29  58000  59600  57300  59600  28369314  2.581756
# 202  2024-10-31  58500  61200  58300  59200  35809196  0.169205
# 204  2024-11-04  58600  59400  58400  58700  15586947  0.686106
# 207  2024-11-07  56900  58100  56800  57500  17043102  0.349040
# 213  2024-11-15  50300  54200  50300  53500  43748624  7.214429
#
# [102 rows x 7 columns]

# %%
# change 가 0 미만인 데이터 출력
# Out:
#            date   open   high    low  close    volume    change
# 1    2024-01-03  78500  78800  77000  77000  21753644 -3.266332
# 2    2024-01-04  76100  77300  76100  76600  15324439 -0.519481
# 4    2024-01-08  77000  77500  76400  76500  11088724 -0.130548
# 5    2024-01-09  77400  77700  74300  74700  26019249 -2.352941
# 6    2024-01-10  75000  75200  73200  73600  20259529 -1.472557
# ..          ...    ...    ...    ...    ...       ...       ...
# 208  2024-11-08  58000  58300  57000  57000  13877396 -0.869565
# 209  2024-11-11  56700  56800  55000  55000  29811326 -3.508772
# 210  2024-11-12  54600  54600  53000  53000  37962881 -3.636364
# 211  2024-11-13  52000  53000  50500  50600  52527995 -4.528302
# 212  2024-11-14  50200  51800  49900  49900  48510715 -1.383399
#
# [112 rows x 7 columns]

# %%
# moving_avg_20d 열 추가 후 출력
# Out:
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
#         ...
# 209    58255.0
# 210    57855.0
# 211    57410.0
# 212    56920.0
# 213    56635.0
# Name: moving_avg_20d, Length: 210, dtype: float64
# /var/folders/j1/4jh28fnd32qfskt1f42frh980000gn/T/ipykernel_4762/617904133.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['moving_avg_20d'] = df['close'].rolling(window=20).mean()

# %%
# moving_avg_20d 열 시각화

# %%
# moving_avg_60d 열 추가

# %%
# drop NaN 행

# %%
# moving_avg_20d, moving_avg_60d 열 시각화 (x축은 date, 표의 크기는 20x5)
